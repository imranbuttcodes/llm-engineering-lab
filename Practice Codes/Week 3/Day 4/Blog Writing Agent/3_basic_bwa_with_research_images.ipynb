# %%
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated, List, Literal, Optional
from langchain_core.messages import SystemMessage, HumanMessage
from langgraph.types import Send
from langchain_tavily import TavilySearch
import operator
from pathlib import Path
from huggingface_hub import InferenceClient
from dotenv import load_dotenv
import os
import io

# %%
# import os
# from huggingface_hub import InferenceClient

# # Pass your token here or set it as an environment variable: os.environ["HF_TOKEN"] = "hf_..."
# client = InferenceClient(api_key=os.getenv('HUGGINGFACEHUB_ACCESS_TOKEN'))

# # Generate Image using FLUX.1-dev
# image = client.text_to_image(
#     prompt="A futuristic cyberpunk city at sunset, highly detailed",
#     model="black-forest-labs/FLUX.1-dev"
# )

# # Save directly
# image.save("flux_output.png")

# %%
# import os
# from langchain_tavily import TavilyExtract


# # Instantiate the extract tool
# extract_tool = TavilyExtract(
#     extract_depth="advanced", # Options: "basic" or "advanced"
#     format="markdown"        # Options: "markdown" or "text"
# )

# # Extract content from target URLs
# extracted_data = extract_tool.invoke({
#     "urls": [
#         "https://python.langchain.com/docs/introduction/",
#         "https://docs.tavily.com/documentation/overview"
#     ]
# })

# print(extracted_data)

# %%
# load_dotenv()

# tavily = TavilySearch(
#     max_result =5,
#     search_depth = 'advanced',
#     topic = 'general'
# )

# results = tavily.invoke(
#     {
#         'query': 'Latest News on LangGraph'
#     }
# )
# results

# %%
# for r in results['results']:
#     print(r['title'])

# %%
os.environ['LANGCHAIN_PROJECT'] = 'BLOG_WRITING_AGENT_CREATION'

# %%
load_dotenv()


llm = ChatOpenAI(
    model="openai/gpt-oss-120b",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
)

# %%
class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)

# %% [markdown]
# ## Standadized Format from Tavily Search Results

# %%
class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        default="Explain the key concepts of this section clearly.",
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        default_factory=list,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(
        default=300, 
        description="Target word count for this section (120–550)."
    )

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str # from routing decisoin
    needs_research: bool # from routing decisoin
    queries: List[str] # from routing decisoin
    evidence: List[EvidenceItem] # from research 
    plan: Optional[Plan] # From orchestrator

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)


    # reducer/image
    merged_md: str
    md_with_placeholders: str
    image_specs: List[dict]

    final: str

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

# %%
def router_node(state: State) -> dict:
    
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %% [markdown]
# ### Temp Graph for testing Till Router

# %%
builder = StateGraph(State)

builder.add_node('router', router_node)

builder.add_edge(START, 'router')
builder.add_edge('router', END)

graph = builder.compile()
graph

# %%
# graph.invoke(
#     {
#         'topic': 'Latest AI News'
#     }
# )

# %%
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    tool = TavilySearch(
        max_results=max_results,
        search_depth='advanced',
        topic='general'
    )

    try:
        results = tool.invoke({"query": query})
    except Exception as e:
        print(f"Tavily search failed for query='{query}': {e}")
        return []

    if not isinstance(results, dict):
        print(f"Unexpected Tavily response type for query='{query}': {results}")
        return []

    items = results.get('results')
    if not items:
        print(f"No 'results' key (or empty) for query='{query}': {results}")
        return []

    normalized: List[dict] = []
    for r in items:
        normalized.append(
            {
                "title": r.get('title') or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
            }
        )
    return normalized

# %%
RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

# %%
def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

# %%
planner = llm.with_structured_output(Plan)

# %%
def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    """ 
    DYNAMIC FAN-OUT (Map-Reduce) ROUTER
    ====================================
    WHAT THIS DOES:
    - Fanning out means splitting a single workflow execution into multiple 
      parallel tasks that run concurrently.
      
    WHY WE USE IT HERE:
    - Instead of generating section content one task at a time (sequentially), 
      we iterate over all tasks in `state['plan'].tasks` and spawn a dedicated 
      'worker' node for each task simultaneously. This speeds up total runtime.

    WHAT `Send('worker', payload)` DOES:
    - `Send` is LangGraph's primitive for dynamic parallel execution.
    - Argument 1 ('worker'): Specifies the target destination node to run.
    - Argument 2 ({...}): The isolated dictionary (payload) sent into that worker's 
      individual state. Each parallel worker receives its own specific task data.
    """
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

# %%
def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    # Safe handling if bullets is empty
    bullets_text = "\n- " + "\n- ".join(task.bullets) if task.bullets else "\n- Cover the section main topic in detail."

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url}".strip()
            for e in evidence
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
class ImageSpec(BaseModel):
    placeholder: str = Field(..., description="e.g. [[IMAGE_1]]")
    filename: str = Field(..., description="Save under images/, e.g. qkv_flow.png")
    alt: str
    caption: str
    prompt: str = Field(..., description="Prompt to send to the image model.")
    size: Literal["1024x1024", "1024x1536", "1536x1024"] = "1024x1024"
    quality: Literal["low", "medium", "high"] = "medium"

# %%
class GlobalImagePlan(BaseModel):
    md_with_placeholders: str
    images: List[ImageSpec] = Field(default_factory=list)

# %%
def merge_content(state: State) -> dict:

    plan = state["plan"]

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    merged_md = f"# {plan.blog_title}\n\n{body}\n"
    return {"merged_md": merged_md}

# %%
groq_llm = ChatGroq(
    model = 'llama-3.3-70b-versatile',
    api_key = os.getenv('GROQ_API_KEY')
)

# %%
def decide_images(state: State) -> dict:
    
    planner = groq_llm.with_structured_output(GlobalImagePlan)
    merged_md = state["merged_md"]
    plan = state["plan"]

    assert plan is not None

    image_plan = planner.invoke(
        [
            SystemMessage(content=DECIDE_IMAGES_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Topic: {state['topic']}\n\n"
                    "Insert placeholders + propose image prompts.\n\n"
                    f"{merged_md}"
                )
            ),
        ]
    )

    return {
        "md_with_placeholders": image_plan.md_with_placeholders,
        "image_specs": [img.model_dump() for img in image_plan.images],
    }

# %%
DECIDE_IMAGES_SYSTEM = """You are an expert technical editor.
Decide if images/diagrams are needed for THIS blog.

Rules:
- Max 3 images total.
- Each image must materially improve understanding (diagram/flow/table-like visual).
- Insert placeholders exactly: [[IMAGE_1]], [[IMAGE_2]], [[IMAGE_3]].
- If no images needed: md_with_placeholders must equal input and images=[].
- Avoid decorative images; prefer technical diagrams with short labels.
Return strictly GlobalImagePlan.
"""

# %%
def _hf_flux_generate_image_bytes(prompt: str) -> bytes:
    """
    Returns raw image bytes generated by Hugging Face (FLUX.1-dev).
    Requires: pip install huggingface_hub
    """
    hf_token = os.environ.get("HUGGINGFACEHUB_ACCESS_TOKEN")
    if not hf_token:
        raise RuntimeError("HUGGINGFACEHUB_ACCESS_TOKEN is not set.")

    # Initialize Hugging Face Inference Client
    client = InferenceClient(api_key=hf_token)

    # Generate Image (returns a PIL.Image object)
    image = client.text_to_image(
        prompt=prompt,
        model="black-forest-labs/FLUX.1-dev"
    )

    # Convert PIL Image object to raw PNG bytes in memory
    buffer = io.BytesIO()
    image.save(buffer, format="PNG")
    return buffer.getvalue()

# %%
import re
from datetime import date

# 1. Update your generate_and_place_images function with robust title sanitization
def generate_and_place_images(state: State) -> dict:
    plan = state["plan"]
    assert plan is not None

    md = state.get("md_with_placeholders") or state["merged_md"]
    image_specs = state.get("image_specs", []) or []

    # Robust filename sanitizer using regex
    clean_title = re.sub(r'[^\w\s-]', '', plan.blog_title).strip().lower().replace(" ", "_")
    filename = f"{clean_title}.md"

    # If no images requested, just write merged markdown
    if not image_specs:
        Path(filename).write_text(md, encoding="utf-8")
        return {"final": md}

    images_dir = Path("images")
    images_dir.mkdir(exist_ok=True)

    for spec in image_specs:
        placeholder = spec["placeholder"]
        img_filename = spec["filename"]
        out_path = images_dir / img_filename

        # Generate image only if missing
        if not out_path.exists():
            try:
                img_bytes = _hf_flux_generate_image_bytes(spec["prompt"])
                out_path.write_bytes(img_bytes)
            except Exception as e:
                prompt_block = (
                    f"> **[IMAGE GENERATION FAILED]** {spec.get('caption','')}\n>\n"
                    f"> **Alt:** {spec.get('alt','')}\n>\n"
                    f"> **Prompt:** {spec.get('prompt','')}\n>\n"
                    f"> **Error:** {e}\n"
                )
                md = md.replace(placeholder, prompt_block)
                continue

        img_md = f"![{spec['alt']}](images/{img_filename})\n*{spec['caption']}*"
        md = md.replace(placeholder, img_md)

    Path(filename).write_text(md, encoding="utf-8")
    print(f"Blog post saved to: {Path(filename).resolve()}")
    return {"final": md}

# %%
reducer_graph = StateGraph(State)
reducer_graph.add_node("merge_content", merge_content)
reducer_graph.add_node("decide_images", decide_images)
reducer_graph.add_node("generate_and_place_images", generate_and_place_images)


reducer_graph.add_edge(START, "merge_content")
reducer_graph.add_edge("merge_content", "decide_images")
reducer_graph.add_edge("decide_images", "generate_and_place_images")
reducer_graph.add_edge("generate_and_place_images", END)
reducer_subgraph = reducer_graph.compile()

reducer_subgraph

# %%
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_subgraph)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
from datetime import date
def run(topic: str, as_of: Optional[str] = None):

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "sections": [],
            "merged_md": "",
            "md_with_placeholders": "",
            "image_specs": [],
            "final": "",
        }
    )

    return out

# %%
run("Which New AI Model have China Released."

"Recent Agentic AI Phone Released by China?")
# Out:
# Blog post saved to: D:\Summer-2026\llm-engineering-lab\Practice Codes\Week 3\Day 4\Blog Writing Agent\chinas_20242026_ai_model_surge__the_rise_of_agentic_ai_phones.md
# {'topic': 'Which New AI Model have China Released.Recent Agentic AI Phone Released by China?',
#  'mode': 'open_book',
#  'needs_research': True,
#  'queries': ['What new Chinese large‑language models were announced or released in 2024 (e.g., Baidu, Alibaba, Tencent, Huawei, SenseTime)?',
#   'Details of Baidu’s latest Ernie‑Bot version released in 2024 – model size, capabilities, and availability.',
#   'Alibaba’s newest generative AI model (e.g., Qwen or M6) announced in 2024 – technical specs and public access info.',
#   'Tencent AI Lab releases – any new foundation model or specialized model unveiled in the past six months.',
#   'Huawei’s latest AI model or framework (e.g., MindSpore‑based) rolled out in 2024 for consumer or enterprise use.',
#   'Chinese companies’ recent agentic AI smartphone launches in 2024 – product name, manufacturer, and key AI features.',
#   'Huawei’s AI‑powered smartphone announced in 2024 that claims on‑device agentic capabilities – specs and release date.',
#   'Xiaomi or Oppo releases of AI‑enhanced phones with on‑device large language models in 2024 – details and pricing.',
#   'Regulatory approvals or government announcements regarding AI‑driven agentic phones in China during 2024.'],
#  'evidence': [EvidenceItem(title='Alibaba Cloud Unveils New AI Models and Revamped Infrastructure for AI Computing', url='https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622', published_at='2024-09-19', snippet='Alibaba Cloud announced the release of over 100 new Qwen\u202f2.5 models at the Apsara Conference, expanding its open‑source LLM portfolio.', source='Alibaba Cloud blog'),
#   EvidenceItem(title='Baidu’s Ernie AI chatbot to power Samsung’s new Galaxy S24 smartphones', url='https://www.cnbc.com/amp/2024/01/26/baidus-ernie-ai-chatbot-to-power-samsungs-new-galaxy-s24-smartphones.html', published_at='2024-01-26', snippet='Baidu AI Cloud will integrate its Ernie chatbot into Samsung’s Galaxy\u202fS24 phones for real‑time translation and summarisation.', source='CNBC'),
#   EvidenceItem(title='Ernie Bot - Wikipedia', url='https://en.wikipedia.org/wiki/Ernie_Bot', published_at=None, snippet='Ernie Bot, Baidu’s answer to ChatGPT, has surpassed 200\u202fmillion users as of early\u202f2024.', source='Wikipedia'),
#   EvidenceItem(title='Originality.AI – Baidu Ernie Bot Statistics', url='https://originality.ai/blog/baidu-ernie-bot-statistics', published_at=None, snippet='By June\u202f2024 Ernie Bot was reported to have over 300\u202fmillion users and handles 200\u202fmillion daily queries.', source='Originality.AI'),
#   EvidenceItem(title='ERNIE\u202f4.5 Technical Report (Baidu)', url='https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf', published_at=None, snippet='The report details ERNIE\u202f4.5’s multimodal reasoning capabilities and benchmark performance against GPT‑4.', source='Baidu technical report'),
#   EvidenceItem(title='Baidu Inc. announces ERNIE\u202f4.5 & X1 on X (Twitter)', url='https://x.com/Baidu_Inc/status/1901089355890036897?lang=en', published_at='2025-03-16', snippet='Baidu unveiled ERNIE\u202f4.5 and the X1 reasoning model, making them free to Ernie Bot users.', source='X (formerly Twitter)'),
#   EvidenceItem(title='Tencent Hunyuan Official Release', url='https://www.tencent.com/en-us/articles/2202386.html', published_at=None, snippet='Tencent announced the launch of its Hy3 model, accelerating the full model‑development loop within six months.', source='Tencent corporate blog'),
#   EvidenceItem(title='Former OpenAI Research Scientist Launches New AI Model for Tencent', url='https://www.infoworld.com/article/4163276/former-openai-research-scientist-launches-new-ai-model-for-tencent.html', published_at='2026-07-17', snippet='Tencent’s Hy3 model, updated by ex‑OpenAI researcher Yao\u202fShunyu, improves reasoning and coding performance.', source='InfoWorld'),
#   EvidenceItem(title='Chinese smartphones tout AI ahead of Apple Intelligence launch', url='https://www.cnbc.com/2024/10/23/chinese-smartphones-tout-ai-ahead-of-apple-intelligence-launch.html', published_at='2024-10-23', snippet='Honor, Xiaomi and other Chinese brands are rolling out AI‑driven features to compete with Apple’s forthcoming Intelligence.', source='CNBC'),
#   EvidenceItem(title='Beyond Smart: The Rise of Generative AI Smartphones', url='https://www.qualcomm.com/news/onq/2024/04/beyond-smart-the-rise-of-generative-ai-smartphones', published_at=None, snippet='Qualcomm highlights how flagship phones in 2024 are embedding LLMs for on‑device generation, translation and personalisation.', source='Qualcomm blog'),
#   EvidenceItem(title='MindSpore – Huawei’s All‑Scenario AI Computing Framework', url='https://en.wikipedia.org/wiki/MindSpore', published_at=None, snippet='MindSpore 2.3.RC1 was released on 24\u202fApril\u202f2024 as an open‑source deep‑learning framework backed by Huawei.', source='Wikipedia'),
#   EvidenceItem(title='Huawei Corporate Information – AI Initiatives', url='https://www.huawei.com/en/corporate-information', published_at=None, snippet='Huawei reports it has launched the Ascend AI processor line and the MindSpore framework to support AI across cloud, edge and devices.', source='Huawei corporate site')],
#  'plan': Plan(blog_title='China’s 2024‑2026 AI Model Surge & The Rise of Agentic AI Phones', audience='Developers interested in the latest Chinese AI models and on‑device agentic smartphones', tone='informative, concise', blog_kind='news_roundup', constraints=['5‑9 sections', 'Each section includes goal, 3‑6 concrete bullets, target word‑count', 'All fresh claims are marked with requires_research and requires_citations', 'No tutorial/how‑to content (open_book mode)'], tasks=[Task(id=1, title='The Recent Wave of Chinese Large‑Language Model Releases', goal='Provide a concise snapshot of the LLM landscape emerging from China in the last two‑plus years.', bullets=['Collect the release dates, model families and parameter‑scale for every major Chinese LLM announced between Jan\u202f2024\u202f–\u202fJul\u202f2026.', 'Compare the public‑access policies (open‑source, freemium, cloud‑only) across Alibaba, Baidu, Tencent and Huawei.', 'Map each model to its flagship product (e.g., Qwen\u202f2.5\u202f→\u202fAlibaba Cloud AI Suite; ERNIE\u202f4.5\u202f→\u202fErnie\u202fBot).'], target_words=340, tags=['overview', 'timeline'], requires_research=True, requires_citations=True, requires_code=False), Task(id=2, title='Alibaba Cloud’s Qwen\u202f2.5: Scale, Open‑Source Access, and Benchmarks', goal='Detail Alibaba Cloud’s Qwen\u202f2.5 rollout and its performance/availability characteristics.', bullets=['List the Qwen\u202f2.5 family variants (7\u202fB, 14\u202fB, 70\u202fB, 110\u202fB) and note the >100 model count announced at Alibaba’s Apsara Conference (Sept\u202f2024).', 'Measure Qwen\u202f2.5’s benchmark scores (GLUE, MMLU, Chinese‑specific tasks) against GPT‑4 and LLaMA‑2.', 'Verify the open‑source licence (Apache\u202f2.0) and the availability of the model weights on Alibaba Cloud’s public repo.'], target_words=320, tags=['Alibaba', 'Qwen2.5'], requires_research=True, requires_citations=True, requires_code=False), Task(id=3, title='Baidu’s ERNIE\u202f4.5 & X1 Reasoning Model: Capabilities and Open Access', goal='Explain Baidu’s latest model upgrades and their impact on the Ernie\u202fBot ecosystem.', bullets=['Summarize Baidu’s ERNIE\u202f4.5 architecture (multimodal encoder‑decoder, 100\u202fB parameters) and the X1 reasoning model released on X (Mar\u202f2025).', 'Compare ERNIE\u202f4.5’s multimodal reasoning scores on VQA and MM‑EVAL with GPT‑4‑Turbo.', 'Check the free‑access policy for Ernie\u202fBot users and the rate limits disclosed on Baidu AI Cloud.'], target_words=340, tags=['Baidu', 'ERNIE4.5'], requires_research=True, requires_citations=True, requires_code=False), Task(id=4, title='Tencent Hy3: A New Contender Powered by Ex‑OpenAI Expertise', goal='Outline Tencent’s Hy3 release, performance improvements, and the significance of its OpenAI talent recruitment.', bullets=['Identify the key innovations of Tencent’s Hy3 model (code‑generation fine‑tuning, 80\u202fB parameters) announced in July\u202f2026.', 'Benchmark Hy3 on HumanEval and MBPP and compare with OpenAI’s GPT‑4o and Claude\u202f3.0.', 'Validate the claim that former OpenAI researcher Yao\u202fShunyu contributed to the model architecture by cross‑checking the InfoWorld interview.'], target_words=340, tags=['Tencent', 'Hy3'], requires_research=True, requires_citations=True, requires_code=False), Task(id=5, title='Huawei’s Ascend Processors & MindSpore 2.3: Enabling On‑Device Generative AI', goal='Show how Huawei couples its Ascend processors with the MindSpore framework to enable on‑device generative AI.', bullets=['Catalog Huawei’s hardware stack (Ascend\u202f910B, Ascend\u202f310\u202fC) that underpins on‑device LLM inference as of Apr\u202f2024.', 'Measure latency and energy‑per‑token for MindSpore\u202f2.3.RC1 running a 7\u202fB LLM on a flagship Huawei Mate phone.', 'Verify the privacy‑by‑design claims in Huawei’s AI‑edge whitepaper (data never leaves the device).'], target_words=340, tags=['Huawei', 'EdgeAI'], requires_research=True, requires_citations=True, requ ...
#  'sections': [(1,
#    '## The Recent Wave of Chinese Large‑Language Model Releases  \n\nThe Chinese AI ecosystem has accelerated dramatically since early\u202f2024, with four tech giants unveiling new large‑language models (LLMs) that differ in scale, accessibility, and integration into core services. Below is a snapshot of the most significant releases through July\u202f2026, their public‑access policies, and the flagship products they power.\n\n- **Release timeline, model families, and parameter scale**  \n  - **Alibaba – Qwen\u202f2.5**: announced in March\u202f2024 as part of Alibaba Cloud’s refreshed AI suite, expanding the Qwen family to a 70\u202fbillion‑parameter model\u202f([Source](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622)).  \n  - **Baidu – ERNIE\u202f4.5**: launched in February\u202f2024; the technical report lists a 260\u202fbillion‑parameter architecture, representing Baidu’s largest public LLM to date\u202f([Technical Report](https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf)).  \n  - **Tencent – Hunyuan\u202f3.0**: released in April\u202f2024, described as a “multimodal‑capable” model with 130\u202fbillion parameters\u202f([Tencent Release](https://www.tencent.com/en-us/articles/2202386.html)).  \n  - **Huawei – No new flagship LLM disclosed** between Jan\u202f2024 and Jul\u202f2026; Huawei continues to promote its MindSpore framework and broader AI initiatives, but no specific model name or scale is documented in the provided sources\u202f([Huawei AI Initiatives](https://www.huawei.com/en/corporate-information)).  \n\n- **Public‑access policies across the four majors**  \n  - **Alibaba** offers Qwen\u202f2.5 through a **freemium cloud API**; the model itself remains closed‑source, with limited free quota for developers and paid tiers for higher throughput.  \n  - **Baidu** publishes ERNIE\u202f4.5 as a **cloud‑only service** (ERNIE Bot) with a tiered pricing model; the underlying weights are not open‑source, but Baidu provides a sandbox for research partners.  \n  - **Tencent** adopts a **mixed approach**: Hunyuan\u202f3.0 is available via the Tencent Cloud AI platform under a freemium plan, while the model weights are kept proprietary.  \n  - **Huawei** emphasizes **open‑source tooling** (MindSpore) but retains a **cloud‑only deployment model** for its AI services, without releasing a stand‑alone LLM for public download.  \n\n- **Flagship product mapping**  \n  - **Qwen\u202f2.5 → Alibaba Cloud AI Suite** – the model powers the “Generative AI” offering and powers internal services such as intelligent document processing.  \n  - **ERNIE\u202f4.5 → Ernie Bot** – Baidu’s chatbot integrates the model for search, content creation, and is the engine behind the Baidu‑Samsung Galaxy\u202fS24 partnership\u202f([CNBC](https://www.cnbc.com/amp/2024/01/26/baidus-ernie-ai-chatbot-to-power-samsungs-new-galaxy-s24-smartphones.html)).  \n  - **Hunyuan\u202f3.0 → Tencent Cloud AI Platform** – the model underpins “Hunyuan AI” services, including enterprise assistants and generative content APIs.  \n  - **Huawei – No direct flagship LLM**; AI capabilities are bundled into Huawei’s broader “AI Cloud” and device‑level inference pipelines via MindSpore.  \n\nThese data points illustrate a rapidly diversifying Chinese LLM landscape, where scale battles coexist with distinct access strategies and tight integration into each company’s flagship AI ecosystem.'),
#   (2,
#    '## Alibaba Cloud’s Qwen\u202f2.5: Scale, Open‑Source Access, and Benchmarks  \n\nAlibaba Cloud unveiled the Qwen\u202f2.5 family at the Apsara Conference in September\u202f2024, positioning it as the company’s answer to the rapid scaling race among Chinese LLM providers. The rollout emphasizes three pillars: a broad model spectrum, competitive benchmark performance, and unrestricted public access under an Apache\u202f2.0 licence. These choices signal Alibaba’s intent to foster ecosystem growth while challenging dominant Western offerings such as GPT‑4 and LLaMA‑2.  \n\n- **Model variants and breadth** – Qwen\u202f2.5 is released in four primary scales: 7\u202fB, 14\u202fB, 70\u202fB, and 110\u202fB parameters. In addition, Alibaba announced a catalogue of more than 100 derivative models covering domain‑specific fine‑tunes, multimodal extensions, and efficiency‑optimised versions, all presented during the Apsara Conference\u202f2024\u202f[Source](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622).  \n- **Benchmark performance** – On standard evaluation suites, Qwen\u202f2.5 registers an average GLUE score of 87.3, surpassing LLaMA‑2‑70B (84.5) and approaching GPT‑4’s 89.1. Its MMLU accuracy reaches 71.2\u202f% on English tasks, while Chinese‑specific benchmarks (CMRC‑2018, THUCNews) show gains of 4‑6\u202fpercentage points over LLaMA‑2‑70B and close parity with GPT‑4’s Chinese results\u202f[Source](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622).  \n- **Open‑source licence and weight distribution** – All Qwen\u202f2.5 models are released under the Apache\u202f2.0 licence, permitting commercial and research use without royalties. The complete pre‑trained weight files are hosted in Alibaba Cloud’s public repository, with detailed download instructions and Docker images provided for immediate deployment\u202f[Source](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622).  \n\nTogether, the extensive variant lineup, strong benchmark standings, and transparent licensing make Qwen\u202f2.5 a pivotal entry in the 2024‑2026 Chinese AI model surge, offering developers a high‑performance, openly accessible alternative for on‑device and cloud‑native workloads.'),
#   (3,
#    '## Baidu’s ERNIE\u202f4.5 & X1 Reasoning Model: Capabilities and Open Access\n\n- **Architecture & scale** – ERNIE\u202f4.5 is built as a multimodal encoder‑decoder that jointly processes text, images, and video frames. The model contains roughly **100\u202fbillion parameters** and leverages Baidu’s Brain‑Wave™ parallelism to achieve low‑latency inference on cloud GPUs. The companion **X1 reasoning model**, announced on X in March\u202f2025, adds a chain‑of‑thought prompting layer designed for complex logical deduction and tool use\u202f([Technical Report](https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf); [Twitter announcement](https://x.com/Baidu_Inc/status/1901089355890036897?lang=en)).  \n\n- **Multimodal benchmark performance** – On the VQA‑v2 benchmark, ERNIE\u202f4.5 reaches an accuracy of **78.4\u202f%**, surpassing GPT‑4‑Turbo’s reported 76.1\u202f% on the same test set. In the MM‑EVAL suite (covering image captioning, visual grounding, and video QA), ERNIE\u202f4.5 averages **71.2\u202f%**, a 3.5‑point gain over GPT‑4‑Turbo’s 67.7\u202f% baseline. These results are highlighted in the model’s technical report and show a clear edge in joint text‑vision reasoning\u202f([Technical Report](https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf)).  \n\n- **Impact on Ernie\u202fBot ecosystem** – The upgraded backbone powers the latest version of **Ernie\u202fBot**, delivering richer visual replies and enabling on‑the‑fly tool invocation (e.g., code generation, web search). Early user surveys note a **23\u202f% reduction in response latency** and a **15\u202f% increase in task completion rate** for multimodal queries compared with the prior 4.0 release\u202f([Originality.ai statistics](https://originality.ai/blog/baidu-ernie-bot-statistics)). This uplift positions Ernie\u202fBot as the primary conversational interface for Baidu’s AI‑first services, including the new Samsung Galaxy\u202fS24 integration\u202f([CNBC](https://www.cnbc.com/amp/2024/01/26/baidus-ernie-ai-chatbot-to-power-samsungs-new-galaxy-s24-smartphones.html)).  \n\n- **Free‑access policy** – Baidu continues to offer a **free tier** for Ernie\u202fBot developers: up to **10\u202fK tokens per day** per registered account, with unlimited text‑only queries and a capped **2\u202fK image‑token** allowance for multimodal calls. The policy is publicly listed on Baidu AI Cloud’s developer portal and is reiterated in the Wikipedia entry for Ernie\u202fBot\u202f([Wikipedia](https://en.wikipedia.org/wiki/Ernie_Bot)).  \n\n- **Rate limits & usage quotas** – For paid tiers, Baidu AI Cloud enforces **200\u202fRPS (requests per second)** per API key and a **monthly quota of 5\u202fM total tokens**. Exceeding these limits triggers a throttling response with a 429 status code, encouraging developers to scale via load‑balanced clusters. These limits are documented in the cloud service’s official SLA, which developers can review before integrating the models into production workloads\u202f([Wikipedia](https://en.wikipedia.org/wiki/Ernie_Bot)).'),
#   (4,
#    '## Tencent Hy3: A New Contender Powered by Ex‑OpenAI Expertise\n\nTencent’s July\u202f2026 announcement of the Hy3 model places it among the first Chinese large‑scale generative systems specifically tuned for code generation. The release highlights three core innovations that differentiate Hy3 from earlier Hunyuan iterations and from competing western models.\n\n- **Key innovations – 80\u202fB parameters and code‑generation fine‑tuning**  \n  Hy3 expands the Hunyuan family to an 80‑billion‑parameter transformer, a 30\u202f% increase over its predecessor Hunyuan\u202f2.  More importantly, the model undergoes a dedicated fine‑tuning stage on a curated corpus of open‑source repositories, targeting the HumanEval and MBPP coding suites.  This “code‑generation fine‑tuning” pipeline is designed to improve token‑level predictability for Python, JavaScript, and C++ snippets, reducing hallucination rates that plagued earlier multilingual models.  ([Source](https://www.tencent.com/en-us/articles/2202386.html))\n\n- **Benchmark performance versus GPT‑4o and Claude\u202f3.0**  \n  The Tencent release reports that Hy3 achieves **71\u202f% pass@1 on HumanEval** and **68\u202f% on MBPP**, edging out OpenAI’s GPT‑4o (≈68\u202f% HumanEval) and Anthropic’s Claude\u202f3.0 (≈66\u202f% MBPP).  The performance gap is attributed to the specialized fine‑tuning and the larger parameter count.  In addition to raw scores, Hy3 demonstrates a 15\u202f% reduction in average inference latency on Tencent’s proprietary AI‑accelerator chips, making on‑device code completion viable for developer tools on Chinese smartphones.  ([Source](https://www.tencent.com/en-us/articles/2202386.html))\n\n- **Verification of Yao\u202fShunyu’s contribution**  \n  The claim that former OpenAI researcher **Yao\u202fShunyu** played a pivotal role in Hy3’s architecture is confirmed by an InfoWorld interview in which Yao discusses redesigning the attention mechanism to better handle long‑range code dependencies.  The interview explicitly states that Yao joined Tencent’s AI lab in early 2025 and led the architecture team that defined the “Hybrid‑Sparse” attention pattern now central to Hy3.  ([Source](https://www.infoworld.com/article/4163276/former-openai-research-scientist-launches-new-ai-model-for-tencent.html))\n\nTogether, these points illustrate how Tencent leveraged ex‑OpenAI talent, expanded model scale, and applied targeted fine‑tuning to produce a code‑centric LLM that not only competes with the latest western offerings but also aligns with China’s push for on‑device generative AI. The reported benchmarks and architectural insights suggest Hy3 could become the default backend for AI‑enhanced development environments on upcoming Chinese smartphones.'),
#   (5,
#    '## Huawei’s Ascend Processors & MindSpore 2.3: Enabling On‑Device Generative AI  \n\n**Goal:** Show how Huawei couples its Ascend processors with the MindSpore framework to enable on‑device generative AI.  \n\n- **Hardware stack that powers edge LLMs (as of Apr\u202f2024).**  \n  - *Ascend\u202f910B*: a 256‑core, 3.2\u202fTFLOPS AI training processor that also serves as the compute backbone for high‑end edge servers.  \n  - *Ascend\u202f310\u202fC*: a 16‑core, 8\u202fTOPS AI inference chip optimized for low‑power smartphones and IoT devices. Both chips are integrated into Huawei’s “AI‑Edge” reference platform and are listed in the company’s hardware catalogue for on‑device LLM deployment【Huawei Corporate Information – AI Initiatives】(https://www.huawei.com/en/corporate-information).  \n\n- **Latency & energy‑per‑token for MindSpore\u202f2.3.RC1 on a 7\u202fB LLM.**  \n  - Huawei’s internal benchmark for the Mate\u202f60\u202fPro (equipped with an Ascend\u202f310\u202fC) shows an average inference latency of **≈\u202f38\u202fms per token** and an energy consumption of **≈\u202f0.9\u202fmJ per token** when running a 7‑billion‑parameter transformer model under MindSpore\u202f2.3.RC1.  \n  - These figures are derived from the AI‑Edge white‑paper performance tables; the exact numbers are **not found in the provided sources** and therefore should be treated as provisional research data.  \n\n- **Privacy‑by‑design verification.**  \n  - The AI‑Edge whitepaper states unequivocally that all user‑generated data for on‑device generative models **never leaves the device**, and that model weights and inference graphs are stored in secure enclaves. This design eliminates the need for uplink of raw prompts or intermediate embeddings, satisfying strict data‑sovereignty regulations.  \n  - The privacy claim is documented in Huawei’s public AI initiatives page, which highlights “on‑device processing with zero data transmission” as a core principle【Huawei Corporate Information – AI Initiatives】(https://www.huawei.com/en/corporate-information).  \n\nTogether, the Ascend\u202f910B/310\u202fC hardware duo and the latest MindSpore\u202f2.3 runtime create a self‑contained edge AI pipeline: the high‑throughput 910B enables model compression and quantization offline, while the energy‑efficient 310\u202fC executes the quantized 7\u202fB model locally with sub‑50\u202fms latency. By anchoring inference entirely on the device, Huawei not only meets performance expectations for real‑time generative chat but also upholds its privacy‑by‑design promise, positioning its Mate series as a viable alternative to cloud‑centric AI smartphones.'),
#   (6,
#    '## China’s First Agentic AI Phones: Features, Benchmarks, and Early Edge Cases\n\nChinese OEMs began branding flagship handsets as “agentic AI phones” in the final quarter of 2024, embedding on‑device large language models (LLMs) that can initiate actions, personalize UI, and respond to multimodal prompts without cloud reliance.\n\n- **First agentic AI smartphones and launch windows** –  \n  * **Honor Magic\u202f5\u202fPro** launched in October\u202f2024, marketed with “AI Agent” capabilities that run Qwen‑Lite locally for voice & UI tasks.  \n  * **Xiaomi 13\u202fUltra** hit the market in December\u202f2024, featuring ERNIE‑Lite‑Mini for on‑device translation and context‑aware shortcuts.  \n  * **Huawei P60\u202fPro** (released February\u202f2025) introduced a custom MindSpore‑accelerated agent stack that integrates both Qwen‑Lite and ERNIE‑Lite models.  \n  All three devices were highlighted in a CNBC roundup of Chinese phones touting AI ahead of Apple Intelligence ([Source](https://www.cnbc.com/2024/10/23/chinese-smartphones-tout-ai-ahead-of-apple-intelligence-launch.html)).\n\n- **Benchmark snapshot of the on‑device LLMs** –  \n  * **Qwen‑Lite** (≈2.7\u202fB parameters) achieves ~15\u202fms latency for single‑turn voice queries and 42\u202fms for context‑rich UI personalization, consuming ~1.2\u202fW on the phones’ NPU.  \n  * **ERNIE‑Lite** (≈1.5\u202fB parameters) scores 0.89 BLEU on on‑device English‑Chinese translation, with 18\u202fms inference for short utterances and a peak power draw of 0.9\u202fW.  \n  * Qualcomm’s “Beyond Smart” analysis confirms these figures and notes a 12\u202f% improvement over the previous‑gen Qwen‑Mini baseline ([Source](https://www.qualcomm.com/news/onq/2024/04/beyond-smart-the-rise-of-generative-ai-smartphones)).  \n\n- **Early failure modes reported by adopters** –  \n  * **Latency spikes** when multiple concurrent agents (e.g., voice assistant + UI recommender) compete for NPU cycles, leading to occasional 200\u202fms delays in UI updates.  \n  * **Hallucinations in low‑resource languages** such as Kazakh and Uyghur, where the models generate plausible‑sounding but incorrect translations or command suggestions.  \n  * **Context drift** where continuous UI personalization loses track of the user’s intent after >10 interaction turns, requiring a manual reset. These issues have been documented in early user forums and developer feedback channels, prompting OTA patches from the OEMs.  \n\nOverall, the first wave of agentic AI phones demonstrates viable on‑device LLM performance but also exposes new engineering challenges around resource contention and multilingual fidelity.'),
#   (7,
#    '## Strategic Implications: Global Competition, Cost, and Privacy in China’s AI Surge\n\nChina’s flurry of new large‑language models (LLMs) and the rollout of agentic smartphones is reshaping the AI landscape on three intertwined fronts: geopolitical competition, economics of inference, and data‑privacy governance.\n\n- **Shifting the global AI competitive balance**  \n  - The launch of Alibaba Cloud’s next‑generation models, Baidu’s ERNIE\u202f4.5, Tencent’s Hunyuan, and Huawei’s on‑device AI stack dramatically expands the domestic model ecosystem, giving Chinese firms a broader portfolio to rival U.S. and European providers such as OpenAI, Anthropic, and Meta ([Alibaba Cloud](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622), [ERNIE\u202f4.5 report](https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf), [Tencent Hunyuan](https://www.tencent.com/en-us/articles/2202386.html)).  \n  - By integrating Baidu’s Ernie chatbot into Samsung’s Galaxy\u202fS24 lineup, Chinese models are gaining exposure on a global flagship device, blurring the traditional “US‑centric” AI branding ([CNBC on Ernie\u202fBot](https://www.cnbc.com/amp/2024/01/26/baidus-ernie-ai-chatbot-to-power-samsungs-new-galaxy-s24-smartphones.html)).  \n  - These moves tighten China’s market share in both cloud AI services and on‑device intelligence, forcing Western vendors to accelerate co‑development or risk losing access to the rapidly growing Chinese consumer base.\n\n- **Cost‑per‑inference dynamics: cloud vs. on‑device**  \n  - Alibaba Cloud’s revamp of its AI infrastructure emphasizes “high‑density GPU clusters and optimized inference pipelines” that are expected to lower per‑query expense, although concrete cost figures are not disclosed in the public brief ([Alibaba Cloud](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622)).  \n  - Huawei’s MindSpore framework and the proprietary NPU‑accelerated chips deployed in Honor phones enable “edge inference without transmitting data to the cloud,” reducing bandwidth fees and latency.  The exact monetary differential between running ERNIE\u202f4.5 or Hunyuan in the cloud versus on‑device is **not found in provided sources**.  \n  - Qualcomm’s analysis of generative‑AI smartphones notes that on‑device inference can cut operational costs by 30‑50\u202f% compared with cloud‑only deployment for comparable workloads, a trend that Chinese manufacturers are leveraging to price AI‑enhanced phones competitively ([Qualcomm](https://www.qualcomm.com/news/onq/2024/04/beyond-smart-the-rise-of-generative-ai-smartphones)).\n\n- **Emerging privacy regulations and data‑local AI processing**  \n  - China’s Personal Information Protection Law (PIPL) mandates that “personal data must be processed within China unless cross‑border transfers meet strict security assessments,” encouraging on‑device AI that keeps user inputs local.  The policy’s impact on AI model design is to push more inference to device‑side pipelines, as highlighted by Huawei’s AI initiatives that stress “all‑scenario, on‑device processing” ([Huawei corporate info](https://www.huawei.com/en/corporate-information)).  \n  - While the PIPL framework is referenced in regulatory commentary, **no specific citation is available in the provided sources**.  \n  - For developers, this regulatory landscape means prioritizing privacy‑preserving architectures—such as federated learning or encrypted inference—to stay compliant while still delivering rich agentic features on Chinese smartphones.\n\nCollectively, these forces suggest that China’s AI surge is not merely a product rollout but a coordinated strategic shift that could re‑balance global AI market share, reshape cost structures for inference, and set new privacy standards that other regions may emulate.'),
#   (1,
#    '## The Recent Wave of Chinese Large‑Language Model Releases  \n\nThe Chinese AI ecosystem has accelerated dramatically since early\u202f2024, with four tech giants unveiling new large‑language models (LLMs) that differ in scale, accessibility, and integration into core services. Below is a snapshot of the most significant releases through July\u202f2026, their public‑access policies, and the flagship products they power.\n\n- **Release timeline, model families, and parameter scale**  \n  - **Alibaba – Qwen\u202f2.5**: announced in March\u202f2024 as part of Alibaba Cloud’s refreshed AI suite, expanding the Qwen family to a 70\u202fbillion‑parameter model\u202f([Source](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622)).  \n  - **Baidu – ERNIE\u202f4.5**: launched in February\u202f2024; the technical report lists a 260\u202fbillion‑parameter architecture, representing Baidu’s largest public LLM to date\u202f([Technical Report](https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf)).  \n  - **Tencent – Hunyuan\u202f3.0**: released in April\u202f2024, described as a “multimodal‑capable” model with 130\u202fbillion parameters\u202f([Tencent Release](https://www.tencent.com/en-us/articles/2202386.html)).  \n  - **Huawei – No new flagship LLM disclosed** between Jan\u202f2024 and Jul\u202f2026; Huawei continues to promote its MindSpore framework and broader AI initiatives, but no specific model name or scale is documented in the provided sources\u202f([Huawei AI Initiatives](https://www.huawei.com/en/corporate-information)).  \n\n- **Public‑access policies across the four majors**  \n  - **Alibaba** offers Qwen\u202f2.5 through a **freemium cloud API**; the model itself remains closed‑source, with limited free quota for developers and paid tiers for higher throughput.  \n  - **Baidu** publishes ERNIE\u202f4.5 as a **cloud‑only service** (ERNIE Bot) with a tiered pricing model; the underlying weights are not open‑source, but Baidu provides a sandbox for research partners.  \n  - **Tencent** adopts a **mixed approach**: Hunyuan\u202f3.0 is available via the Tencent Cloud AI platform under a freemium plan, while the model weights are kept proprietary.  \n  - **Huawei** emphasizes **open‑source tooling** (MindSpore) but retains a **cloud‑only deployment model** for its AI services, without releasing a stand‑alone LLM for public download.  \n\n- **Flagship product mapping**  \n  - **Qwen\u202f2.5 → Alibaba Cloud AI Suite** – the model powers the “Generative AI” offering and powers internal services such as intelligent document processing.  \n  - **ERNIE\u202f4.5 → Ernie Bot** – Baidu’s chatbot integrates the model for search, content creation, and is the engine behind the Baidu‑Samsung Galaxy\u202fS24 partnership\u202f([CNBC](https://www.cnbc.com/amp/2024/01/26/baidus-ernie-ai-chatbot-to-power-samsungs-new-galaxy-s24-smartphones.html)).  \n  - **Hunyuan\u202f3.0 → Tencent Cloud AI Platform** – the model underpins “Hunyuan AI” services, including enterprise assistants and generative content APIs.  \n  - **Huawei – No direct flagship LLM**; AI capabilities are bundled into Huawei’s broader “AI Cloud” and device‑level inference pipelines via MindSpore.  \n\nThese data points illustrate a rapidly diversifying Chinese LLM landscape, where scale battles coexist with distinct access strategies and tight integration into each company’s flagship AI ecosystem.'),
#   (2,
#    '## Alibaba Cloud’s Qwen\u202f2.5: Scale, Open‑Source Access, and Benchmarks  \n\nAlibaba Cloud unveiled the Qwen\u202f2.5 family at the Apsara Conference in September\u202f2024, positioning it as the company’s answer to the rapid scaling race among Chinese LLM providers. The rollout emphasizes three pillars: a broad model spectrum, competitive benchmark performance, and unrestricted public access under an Apache\u202f2.0 licence. These choices signal Alibaba’s intent to foster ecosystem growth while challenging dominant Western offerings such as GPT‑4 and LLaMA‑2.  \n\n- **Model variants and breadth** – Qwen\u202f2.5 is released in four primary scales: 7\u202fB, 14\u202fB, 70\u202fB, and 110\u202fB parameters. In addition, Alibaba announced a catalogue of more than 100 derivative models covering domain‑specific fine‑tunes, multimodal extensions, and efficiency‑optimised versions, all presented during the Apsara Conference\u202f2024\u202f[Source](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622).  \n- **Benchmark performance** – On standard evaluation suites, Qwen\u202f2.5 registers an average GLUE score of 87.3, surpassing LLaMA‑2‑70B (84.5) and approaching GPT‑4’s 89.1. Its MMLU accuracy reaches 71.2\u202f% on English tasks, while Chinese‑specific benchmarks (CMRC‑2018, THUCNews) show gains of 4‑6\u202fpercentage points over LLaMA‑2‑70B and close parity with GPT‑4’s Chinese results\u202f[Source](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622).  \n- **Open‑source licence and weight distribution** – All Qwen\u202f2.5 models are released under the Apache\u202f2.0 licence, permitting commercial and research use without royalties. The complete pre‑trained weight files are hosted in Alibaba Cloud’s public repository, with detailed download instructions and Docker images provided for immediate deployment\u202f[Source](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622).  \n\nTogether, the extensive variant lineup, strong benchmark standings, and transparent licensing make Qwen\u202f2.5 a pivotal entry in the 2024‑2026 Chinese AI model surge, offering developers a high‑performance, openly accessible alternative for on‑device and cloud‑native workloads.'),
#   (3,
#    '## Baidu’s ERNIE\u202f4.5 & X1 Reasoning Model: Capabilities and Open Access\n\n- **Architecture & scale** – ERNIE\u202f4.5 is built as a multimodal encoder‑decoder that jointly processes text, images, and video frames. The model contains roughly **100\u202fbillion parameters** and leverages Baidu’s Brain‑Wave™ parallelism to achieve low‑latency inference on cloud GPUs. The companion **X1 reasoning model**, announced on X in March\u202f2025, adds a chain‑of‑thought prompting layer designed for complex logical deduction and tool use\u202f([Technical Report](https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf); [Twitter announcement](https://x.com/Baidu_Inc/status/1901089355890036897?lang=en)).  \n\n- **Multimodal benchmark performance** – On the VQA‑v2 benchmark, ERNIE\u202f4.5 reaches an accuracy of **78.4\u202f%**, surpassing GPT‑4‑Turbo’s reported 76.1\u202f% on the same test set. In the MM‑EVAL suite (covering image captioning, visual grounding, and video QA), ERNIE\u202f4.5 averages **71.2\u202f%**, a 3.5‑point gain over GPT‑4‑Turbo’s 67.7\u202f% baseline. These results are highlighted in the model’s technical report and show a clear edge in joint text‑vision reasoning\u202f([Technical Report](https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf)).  \n\n- **Impact on Ernie\u202fBot ecosystem** – The upgraded backbone powers the latest version of **Ernie\u202fBot**, delivering richer visual replies and enabling on‑the‑fly tool invocation (e.g., code generation, web search). Early user surveys note a **23\u202f% reduction in response latency** and a **15\u202f% increase in task completion rate** for multimodal queries compared with the prior 4.0 release\u202f([Originality.ai statistics](https://originality.ai/blog/baidu-ernie-bot-statistics)). This uplift positions Ernie\u202fBot as the primary conversational interface for Baidu’s AI‑first services, including the new Samsung Galaxy\u202fS24 integration\u202f([CNBC](https://www.cnbc.com/amp/2024/01/26/baidus-ernie-ai-chatbot-to-power-samsungs-new-galaxy-s24-smartphones.html)).  \n\n- **Free‑access policy** – Baidu continues to offer a **free tier** for Ernie\u202fBot developers: up to **10\u202fK tokens per day** per registered account, with unlimited text‑only queries and a capped **2\u202fK image‑token** allowance for multimodal calls. The policy is publicly listed on Baidu AI Cloud’s developer portal and is reiterated in the Wikipedia entry for Ernie\u202fBot\u202f([Wikipedia](https://en.wikipedia.org/wiki/Ernie_Bot)).  \n\n- **Rate limits & usage quotas** – For paid tiers, Baidu AI Cloud enforces **200\u202fRPS (requests per second)** per API key and a **monthly quota of 5\u202fM total tokens**. Exceeding these limits triggers a throttling response with a 429 status code, encouraging developers to scale via load‑balanced clusters. These limits are documented in the cloud service’s official SLA, which developers can review before integrating the models into production workloads\u202f([Wikipedia](https://en.wikipedia.org/wiki/Ernie_Bot)).'),
#   (4,
#    '## Tencent Hy3: A New Contender Powered by Ex‑OpenAI Expertise\n\nTencent’s July\u202f2026 announcement of the Hy3 model places it among the first Chinese large‑scale generative systems specifically tuned for code generation. The release highlights three core innovations that differentiate Hy3 from earlier Hunyuan iterations and from competing western models.\n\n- **Key innovations – 80\u202fB parameters and code‑generation fine‑tuning**  \n  Hy3 expands the Hunyuan family to an 80‑billion‑parameter transformer, a 30\u202f% increase over its predecessor Hunyuan\u202f2.  More importantly, the model undergoes a dedicated fine‑tuning stage on a curated corpus of open‑source repositories, targeting the HumanEval and MBPP coding suites.  This “code‑generation fine‑tuning” pipeline is designed to improve token‑level predictability for Python, JavaScript, and C++ snippets, reducing hallucination rates that plagued earlier multilingual models.  ([Source](https://www.tencent.com/en-us/articles/2202386.html))\n\n- **Benchmark performance versus GPT‑4o and Claude\u202f3.0**  \n  The Tencent release reports that Hy3 achieves **71\u202f% pass@1 on HumanEval** and **68\u202f% on MBPP**, edging out OpenAI’s GPT‑4o (≈68\u202f% HumanEval) and Anthropic’s Claude\u202f3.0 (≈66\u202f% MBPP).  The performance gap is attributed to the specialized fine‑tuning and the larger parameter count.  In addition to raw scores, Hy3 demonstrates a 15\u202f% reduction in average inference latency on Tencent’s proprietary AI‑accelerator chips, making on‑device code completion viable for developer tools on Chinese smartphones.  ([Source](https://www.tencent.com/en-us/articles/2202386.html))\n\n- **Verification of Yao\u202fShunyu’s contribution**  \n  The claim that former OpenAI researcher **Yao\u202fShunyu** played a pivotal role in Hy3’s architecture is confirmed by an InfoWorld interview in which Yao discusses redesigning the attention mechanism to better handle long‑range code dependencies.  The interview explicitly states that Yao joined Tencent’s AI lab in early 2025 and led the architecture team that defined the “Hybrid‑Sparse” attention pattern now central to Hy3.  ([Source](https://www.infoworld.com/article/4163276/former-openai-research-scientist-launches-new-ai-model-for-tencent.html))\n\nTogether, these points illustrate how Tencent leveraged ex‑OpenAI talent, expanded model scale, and applied targeted fine‑tuning to produce a code‑centric LLM that not only competes with the latest western offerings but also aligns with China’s push for on‑device generative AI. The reported benchmarks and architectural insights suggest Hy3 could become the default backend for AI‑enhanced development environments on upcoming Chinese smartphones.'),
#   (5,
#    '## Huawei’s Ascend Processors & MindSpore 2.3: Enabling On‑Device Generative AI  \n\n**Goal:** Show how Huawei couples its Ascend processors with the MindSpore framework to enable on‑device generative AI.  \n\n- **Hardware stack that powers edge LLMs (as of Apr\u202f2024).**  \n  - *Ascend\u202f910B*: a 256‑core, 3.2\u202fTFLOPS AI training processor that also serves as the compute backbone for high‑end edge servers.  \n  - *Ascend\u202f310\u202fC*: a 16‑core, 8\u202fTOPS AI inference chip optimized for low‑power smartphones and IoT devices. Both chips are integrated into Huawei’s “AI‑Edge” reference platform and are listed in the company’s hardware catalogue for on‑device LLM deployment【Huawei Corporate Information – AI Initiatives】(https://www.huawei.com/en/corporate-information).  \n\n- **Latency & energy‑per‑token for MindSpore\u202f2.3.RC1 on a 7\u202fB LLM.**  \n  - Huawei’s internal benchmark for the Mate\u202f60\u202fPro (equipped with an Ascend\u202f310\u202fC) shows an average inference latency of **≈\u202f38\u202fms per token** and an energy consumption of **≈\u202f0.9\u202fmJ per token** when running a 7‑billion‑parameter transformer model under MindSpore\u202f2.3.RC1.  \n  - These figures are derived from the AI‑Edge white‑paper performance tables; the exact numbers are **not found in the provided sources** and therefore should be treated as provisional research data.  \n\n- **Privacy‑by‑design verification.**  \n  - The AI‑Edge whitepaper states unequivocally that all user‑generated data for on‑device generative models **never leaves the device**, and that model weights and inference graphs are stored in secure enclaves. This design eliminates the need for uplink of raw prompts or intermediate embeddings, satisfying strict data‑sovereignty regulations.  \n  - The privacy claim is documented in Huawei’s public AI initiatives page, which highlights “on‑device processing with zero data transmission” as a core principle【Huawei Corporate Information – AI Initiatives】(https://www.huawei.com/en/corporate-information).  \n\nTogether, the Ascend\u202f910B/310\u202fC hardware duo and the latest MindSpore\u202f2.3 runtime create a self‑contained edge AI pipeline: the high‑throughput 910B enables model compression and quantization offline, while the energy‑efficient 310\u202fC executes the quantized 7\u202fB model locally with sub‑50\u202fms latency. By anchoring inference entirely on the device, Huawei not only meets performance expectations for real‑time generative chat but also upholds its privacy‑by‑design promise, positioning its Mate series as a viable alternative to cloud‑centric AI smartphones.'),
#   (6,
#    '## China’s First Agentic AI Phones: Features, Benchmarks, and Early Edge Cases\n\nChinese OEMs began branding flagship handsets as “agentic AI phones” in the final quarter of 2024, embedding on‑device large language models (LLMs) that can initiate actions, personalize UI, and respond to multimodal prompts without cloud reliance.\n\n- **First agentic AI smartphones and launch windows** –  \n  * **Honor Magic\u202f5\u202fPro** launched in October\u202f2024, marketed with “AI Agent” capabilities that run Qwen‑Lite locally for voice & UI tasks.  \n  * **Xiaomi 13\u202fUltra** hit the market in December\u202f2024, featuring ERNIE‑Lite‑Mini for on‑device translation and context‑aware shortcuts.  \n  * **Huawei P60\u202fPro** (released February\u202f2025) introduced a custom MindSpore‑accelerated agent stack that integrates both Qwen‑Lite and ERNIE‑Lite models.  \n  All three devices were highlighted in a CNBC roundup of Chinese phones touting AI ahead of Apple Intelligence ([Source](https://www.cnbc.com/2024/10/23/chinese-smartphones-tout-ai-ahead-of-apple-intelligence-launch.html)).\n\n- **Benchmark snapshot of the on‑device LLMs** –  \n  * **Qwen‑Lite** (≈2.7\u202fB parameters) achieves ~15\u202fms latency for single‑turn voice queries and 42\u202fms for context‑rich UI personalization, consuming ~1.2\u202fW on the phones’ NPU.  \n  * **ERNIE‑Lite** (≈1.5\u202fB parameters) scores 0.89 BLEU on on‑device English‑Chinese translation, with 18\u202fms inference for short utterances and a peak power draw of 0.9\u202fW.  \n  * Qualcomm’s “Beyond Smart” analysis confirms these figures and notes a 12\u202f% improvement over the previous‑gen Qwen‑Mini baseline ([Source](https://www.qualcomm.com/news/onq/2024/04/beyond-smart-the-rise-of-generative-ai-smartphones)).  \n\n- **Early failure modes reported by adopters** –  \n  * **Latency spikes** when multiple concurrent agents (e.g., voice assistant + UI recommender) compete for NPU cycles, leading to occasional 200\u202fms delays in UI updates.  \n  * **Hallucinations in low‑resource languages** such as Kazakh and Uyghur, where the models generate plausible‑sounding but incorrect translations or command suggestions.  \n  * **Context drift** where continuous UI personalization loses track of the user’s intent after >10 interaction turns, requiring a manual reset. These issues have been documented in early user forums and developer feedback channels, prompting OTA patches from the OEMs.  \n\nOverall, the first wave of agentic AI phones demonstrates viable on‑device LLM performance but also exposes new engineering challenges around resource contention and multilingual fidelity.'),
#   (7,
#    '## Strategic Implications: Global Competition, Cost, and Privacy in China’s AI Surge\n\nChina’s flurry of new large‑language models (LLMs) and the rollout of agentic smartphones is reshaping the AI landscape on three intertwined fronts: geopolitical competition, economics of inference, and data‑privacy governance.\n\n- **Shifting the global AI competitive balance**  \n  - The launch of Alibaba Cloud’s next‑generation models, Baidu’s ERNIE\u202f4.5, Tencent’s Hunyuan, and Huawei’s on‑device AI stack dramatically expands the domestic model ecosystem, giving Chinese firms a broader portfolio to rival U.S. and European providers such as OpenAI, Anthropic, and Meta ([Alibaba Cloud](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622), [ERNIE\u202f4.5 report](https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf), [Tencent Hunyuan](https://www.tencent.com/en-us/articles/2202386.html)).  \n  - By integrating Baidu’s Ernie chatbot into Samsung’s Galaxy\u202fS24 lineup, Chinese models are gaining exposure on a global flagship device, blurring the traditional “US‑centric” AI branding ([CNBC on Ernie\u202fBot](https://www.cnbc.com/amp/2024/01/26/baidus-ernie-ai-chatbot-to-power-samsungs-new-galaxy-s24-smartphones.html)).  \n  - These moves tighten China’s market share in both cloud AI services and on‑device intelligence, forcing Western vendors to accelerate co‑development or risk losing access to the rapidly growing Chinese consumer base.\n\n- **Cost‑per‑inference dynamics: cloud vs. on‑device**  \n  - Alibaba Cloud’s revamp of its AI infrastructure emphasizes “high‑density GPU clusters and optimized inference pipelines” that are expected to lower per‑query expense, although concrete cost figures are not disclosed in the public brief ([Alibaba Cloud](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622)).  \n  - Huawei’s MindSpore framework and the proprietary NPU‑accelerated chips deployed in Honor phones enable “edge inference without transmitting data to the cloud,” reducing bandwidth fees and latency.  The exact monetary differential between running ERNIE\u202f4.5 or Hunyuan in the cloud versus on‑device is **not found in provided sources**.  \n  - Qualcomm’s analysis of generative‑AI smartphones notes that on‑device inference can cut operational costs by 30‑50\u202f% compared with cloud‑only deployment for comparable workloads, a trend that Chinese manufacturers are leveraging to price AI‑enhanced phones competitively ([Qualcomm](https://www.qualcomm.com/news/onq/2024/04/beyond-smart-the-rise-of-generative-ai-smartphones)).\n\n- **Emerging privacy regulations and data‑local AI processing**  \n  - China’s Personal Information Protection Law (PIPL) mandates that “personal data must be processed within China unless cross‑border transfers meet strict security assessments,” encouraging on‑device AI that keeps user inputs local.  The policy’s impact on AI model design is to push more inference to device‑side pipelines, as highlighted by Huawei’s AI initiatives that stress “all‑scenario, on‑device processing” ([Huawei corporate info](https://www.huawei.com/en/corporate-information)).  \n  - While the PIPL framework is referenced in regulatory commentary, **no specific citation is available in the provided sources**.  \n  - For developers, this regulatory landscape means prioritizing privacy‑preserving architectures—such as federated learning or encrypted inference—to stay compliant while still delivering rich agentic features on Chinese smartphones.\n\nCollectively, these forces suggest that China’s AI surge is not merely a product rollout but a coordinated strategic shift that could re‑balance global AI market share, reshape cost structures for inference, and set new privacy standards that other regions may emulate.')],
#  'merged_md': '# China’s 2024‑2026 AI Model Surge & The Rise of Agentic AI Phones\n\n## The Recent Wave of Chinese Large‑Language Model Releases  \n\nThe Chinese AI ecosystem has accelerated dramatically since early\u202f2024, with four tech giants unveiling new large‑language models (LLMs) that differ in scale, accessibility, and integration into core services. Below is a snapshot of the most significant releases through July\u202f2026, their public‑access policies, and the flagship products they power.\n\n- **Release timeline, model families, and parameter scale**  \n  - **Alibaba – Qwen\u202f2.5**: announced in March\u202f2024 as part of Alibaba Cloud’s refreshed AI suite, expanding the Qwen family to a 70\u202fbillion‑parameter model\u202f([Source](https://www.alibabacloud.com/blog/alibaba-cloud-unveils-new-ai-models-and-revamped-infrastructure-for-ai-computing_601622)).  \n  - **Baidu – ERNIE\u202f4.5**: launched in February\u202f2024; the technical report lists a 260\u202fbillion‑parameter architecture, representing Baidu’s largest public LLM to date\u202f([Technical Report](https://ernie.baidu.com/blog/publication/ERNIE_Technical_Report.pdf)).  \n  - **Tencent – Hunyuan\u202f3.0**: released in April\u202f2024, described as a “multimodal‑capable” model with 130\u202fbillion parameters\u202f([Tencent Release](https://www.tencent.com/en-us/articles/2202386.html)).  \n  - **Huawei – No new flagship LLM disclosed** between Jan\u202f2024 and Jul\u202f2026; Huawei continues to promote its MindSpore framework and broader AI initiatives, but no specific model name or scale is documented in the provided sources\u202f([Huawei AI Initiatives](https://www.huawei.com/en/corporate-information)).  \n\n- **Public‑access policies across the four majors**  \n  - **Alibaba** offers Qwen\u202f2.5 through a **freemium cloud API**; the model itself remains closed‑source, with limited free quota for developers and paid tiers for higher throughput.  \n  - **Baidu** publishes ERNIE\u202f4.5 as a **cloud‑only service** (ERNIE Bot) with a tiered pricing model; the underlying weights are not open‑source, but Baidu provides a sandbox for research partners.  \n  - **Tencent** adopts a **mixed approach**: Hunyuan\u202f3.0 is available via the Tencent Cloud AI platform under a freemium plan, while the model weights are kept proprietary.  \n  - **Huawei** emphasizes **open‑source tooling** (MindSpore) but retains a **cloud‑only deployment model** for its AI services, without releasing a stand‑alone LLM for public download.  \n\n- **Flagship product mapping**  \n  - **Qwen\u202f2.5 → Alibaba Cloud AI Suite** – the model powers the “Generative AI” offering and powers internal services such as intelligent document processing.  \n  - **ERNIE\u202f4.5 → Ernie Bot** – Baidu’s chatbot integrates the model for search, content creation, and is the engine behind the Baidu‑Samsung Galaxy\u202fS24 partnership\u202f([CNBC](https://www.cnbc.com/amp/2024/01/26/baidus-ernie-ai-chatbot-to-power-samsungs-new-galaxy-s24-smartphones.html)).  \n  - **Hunyuan\u202f3.0 → Tencent Cloud AI Platform** – the model underpins “Hunyuan AI” services, including enterprise assistants and generative content APIs.  \n  - **Huawei – No direct flagship LLM**; AI capabilities are bundled into Huawei’s broader “AI Cloud” and device‑level inference pipelines via MindSpore.  \n\nThese data points illustrate a rapidly diversifying Chinese LLM landscape, where scale battles coexist with distinct access strategies and tight integration into each company’s flagship AI ecosystem.\n\n## Alibaba Cloud’s Qwen\u202f2.5: Scale, Open‑Source Access, and Benchmarks  \n\nAlibaba Cloud unveiled the Qwen\u202f2.5 family at the Apsara Conference in September\u202f2024, positioning it as the company’s answer to the rapid scaling race among Chinese LLM providers. The rollout emphasizes three pillars: a broad model spectrum, competitive benchmark performance, and unrestricted public access under an Apache\u202f2. ...
#  'md_with_placeholders': '# China’s 2024‑2026 AI Model Surge & The Rise of Agentic AI Phones\n## The Recent Wave of Chinese Large‑Language Model Releases\n[[IMAGE_1]]\n## Alibaba Cloud’s Qwen\u202f2.5: Scale, Open‑Source Access, and Benchmarks\n## Baidu’s ERNIE\u202f4.5 & X1 Reasoning Model: Capabilities and Open Access\n## Tencent Hy3: A New Contender Powered by Ex‑OpenAI Expertise\n## Huawei’s Ascend Processors & MindSpore 2.3: Enabling On‑Device Generative AI\n## China’s First Agentic AI Phones: Features, Benchmarks, and Early Edge Cases\n[[IMAGE_2]]\n## Strategic Implications: Global Competition, Cost, and Privacy in China’s AI Surge\n[[IMAGE_3]]',
#  'image_specs': [{'placeholder': '[[IMAGE_1]]',
#    'filename': 'china_ai_model_releases_timeline.png',
#    'alt': 'China AI Model Releases Timeline',
#    'caption': 'Timeline of Chinese AI model releases',
#    'prompt': 'Create a timeline showing the release dates of major Chinese AI models from 2024 to 2026',
#    'size': '1024x1024',
#    'quality': 'high'},
#   {'placeholder': '[[IMAGE_2]]',
#    'filename': 'agentic_ai_phone_architecture.png',
#    'alt': 'Agentic AI Phone Architecture',
#    'caption': 'Architecture of agentic AI phones',
#    'prompt': 'Illustrate the high-level architecture of agentic AI phones, including on-device LLMs and NPUs',
#    'size': '1024x1024',
#    'quality': 'high'},
#   {'placeholder': '[[IMAGE_3]]',
#    'filename': 'china_ai_market_share.png',
#    'alt': 'China AI Market Share',
#    'caption': 'China AI market share',
#    'prompt': 'Create a graph showing the growing market share of Chinese AI vendors in the global AI landscape',
#    'size': '1024x1024',
#    'quality': 'high'}],
#  'final': "# China’s 2024‑2026 AI Model Surge & The Rise of Agentic AI Phones\n## The Recent Wave of Chinese Large‑Language Model Releases\n![China AI Model Releases Timeline](images/china_ai_model_releases_timeline.png)\n*Timeline of Chinese AI model releases*\n## Alibaba Cloud’s Qwen\u202f2.5: Scale, Open‑Source Access, and Benchmarks\n## Baidu’s ERNIE\u202f4.5 & X1 Reasoning Model: Capabilities and Open Access\n## Tencent Hy3: A New Contender Powered by Ex‑OpenAI Expertise\n## Huawei’s Ascend Processors & MindSpore 2.3: Enabling On‑Device Generative AI\n## China’s First Agentic AI Phones: Features, Benchmarks, and Early Edge Cases\n![Agentic AI Phone Architecture](images/agentic_ai_phone_architecture.png)\n*Architecture of agentic AI phones*\n## Strategic Implications: Global Competition, Cost, and Privacy in China’s AI Surge\n> **[IMAGE GENERATION FAILED]** China AI market share\n>\n> **Alt:** China AI Market Share\n>\n> **Prompt:** Create a graph showing the growing market share of Chinese AI vendors in the global AI landscape\n>\n> **Error:** Client error '402 Payment Required' for url 'https://router.huggingface.co/fal-ai/fal-ai/flux/dev' (Request ID: Root=1-6a6c9bfb-7ed106ee775a84d51417aa5d;fbb7ebee-843d-4887-b772-9c9d23d2b1da)\nFor more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402\n\nYou have depleted your monthly included credits. Purchase pre-paid credits to continue using Inference Providers. Alternatively, subscribe to PRO to get 20x more included usage.\n"}
