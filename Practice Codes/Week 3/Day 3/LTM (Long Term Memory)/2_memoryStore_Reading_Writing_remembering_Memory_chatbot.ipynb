# %% [markdown]
# # Chatbot Reading Existing Memories

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnableConfig
from langchain_core.messages import SystemMessage

from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.store.memory import InMemoryStore
from langgraph.store.base import BaseStore
import os

# %%
load_dotenv()

llm = ChatOpenAI(
    model="openai/gpt-oss-120b",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
)

# %%
    # ----------------------------
# 1) Create LTM store + seed memories (done BEFORE running the graph)
# ----------------------------
store = InMemoryStore()

user_id = "u1"

# Store user details as a single blob (simple for teaching)
# You can also split into multiple records; this keeps it easy.
user_details = ("user", user_id, "details")

store.put(user_details, "profile_1", {"data": "Name: Imran Butt"})
store.put(user_details, "profile_2", {"data": "Profession: Student Also Learning AI"})
store.put(user_details, "preference_1", {"data": "Prefers concise answers"})
store.put(user_details, "preference_2", {"data": "Likes examples in Python"})
store.put(user_details, "project_1", {"data": "Building MCP servers (Python-based project)"})

# %%
# ----------------------------
# 2) System prompt template (your prompt)
# ----------------------------
SYSTEM_PROMPT_TEMPLATE = """You are a helpful assistant with memory capabilities.
If user-specific memory is available, use it to personalize 
your responses based on what you know about the user.

Your goal is to provide relevant, friendly, and tailored 
assistance that reflects the user’s preferences, context, and past interactions.

If the user’s name or relevant personal context is available, always personalize your responses by:
    – Always Address the user by name (e.g., "Sure, Imran...") when appropriate
    – Referencing known projects, tools, or preferences (e.g., "your MCP  server python based project")
    – Adjusting the tone to feel friendly, natural, and directly aimed at the user

Avoid generic phrasing when personalization is possible. For example, instead of "In TypeScript apps..." 
say "Since your project is built with TypeScript..."

Use personalization especially in:
    – Greetings and transitions
    – Help or guidance tailored to tools and frameworks the user uses
    – Follow-up messages that continue from past context

Always ensure that personalization is based only on known user details and not assumed.

In the end suggest 3 relevant further questions based on the current response and user profile

The user’s memory (which may be empty) is provided as: {user_details_content}
"""

# %%
def chat_node(state: MessagesState, config: RunnableConfig, store: BaseStore):
    
    user_id = config["configurable"]["user_id"]

    # Read-only: fetch user details memory (no writes)
    user_details = ("user", user_id, "details")
    items = store.search(user_details)

    # Convert memory items into a string blob for {user_details_content}
    if items:
        user_details_content = "\n".join(f"- {it.value.get('data', '')}" for it in items)
    else:
        user_details_content = ""  # prompt says it may be empty

    system_prompt = SYSTEM_PROMPT_TEMPLATE.format(
        user_details_content=user_details_content
    )

    system_msg = SystemMessage(content=system_prompt)

    response = llm.invoke([system_msg] + state["messages"])
    return {"messages": [response]}

# %%
builder = StateGraph(MessagesState)
builder.add_node("chat", chat_node)
builder.add_edge(START, "chat")
builder.add_edge("chat", END)

graph = builder.compile(store=store)

graph

# %%
# ----------------------------
# 4) Run it (provide user_id in config)
# ----------------------------
config = {"configurable": {"user_id": "u1"}}

result = graph.invoke(
    {"messages": [{"role": "user", "content": "Explain gen ai in simple terms."}]},
    config,
)

print(result["messages"][-1].content)
# Out:
# **Sure, Imran—here’s a quick, simple rundown of generative AI (Gen AI):**
#
# ---
#
# ### What is Generative AI?
# - **Definition:** A type of artificial intelligence that learns patterns from existing data (like text, images, or sound) and then creates *new* content that looks or sounds similar.
# - **How it works (high‑level):**
#   1. **Training:** Feed a huge dataset to a model (e.g., a neural network). The model adjusts its internal parameters to capture statistical regularities.
#   2. **Generation:** Give the trained model a prompt or seed, and it samples from what it has learned to produce fresh output.
#
# ---
#
# ### Everyday Analogy
# Think of a **mimic artist** who studies thousands of paintings. After enough practice, the artist can paint a brand‑new picture that follows the same style, even though that exact picture never existed before.
#
# ---
#
# ### Core Building Blocks (in Python terms)
# ```python
# from transformers import pipeline
#
# # 1️⃣ Load a pre‑trained generative model (e.g., GPT‑2 for text)
# generator = pipeline('text-generation', model='gpt2')
#
# # 2️⃣ Provide a short prompt
# prompt = "The future of AI in education is"
#
# # 3️⃣ Generate new text
# output = generator(prompt, max_length=50, num_return_sequences=1)
# print(output[0]['generated_text'])
# ```
# - **What happens under the hood?**
#   The model predicts the next word token by token, each time using the words it has already generated as context. The probabilities come from the patterns it learned during training.
#
# ---
#
# ### Why It’s Powerful
# - **Creativity at scale:** Write articles, code snippets, music, or design images automatically.
# - **Customization:** Fine‑tune a base model on your own data (e.g., the logs from your MCP server) to generate domain‑specific content.
#
# ---
#
# ### Quick Caveats (keep them in mind)
# - **Quality depends on data:** Bad or biased training data → low‑quality or biased outputs.
# - **No true understanding:** The model manipulates patterns; it doesn’t “know” the meaning behind them.
# - **Resource‑hungry:** Large models need significant GPU memory and compute.
#
# ---
#
# ### TL;DR (Imran’s preferred style)
# - Gen AI = **learn → mimic → create**.
# - You train on existing data, then ask it to produce new, similar data.
# - A few lines of Python (`transformers` library) can demonstrate it instantly.
#
# ---
#
# #### 👉 Next steps you might find useful
# 1. **Fine‑tune a small model on your MCP server logs** to auto‑generate configuration snippets.
# 2. **Experiment with `openai`'s API** for quick text or code generation without managing GPUs.
# 3. **Explore safety measures** (prompt filtering, bias detection) before deploying any Gen AI feature.
#
# ---
#
# ### Suggested follow‑up questions
# 1. *How can I fine‑tune a generative model on my own Python‑based MCP server data?*
# 2. *What are some lightweight generative models that run on a laptop for quick prototyping?*
# 3. *Can you show a Python example of generating code snippets for my MCP project using an LLM?*

# %%
# ----------------------------
# 4) Run it (provide user_id in config)
# ----------------------------
config = {"configurable": {"user_id": "u1"}}

result = graph.invoke(
    {"messages": [{"role": "user", "content": "What is AI."}]},
    config,
)

print(result["messages"][-1].content)
# Out:
# Hi Imran,
#
# **Artificial Intelligence (AI)** is the field of computer science that creates systems capable of performing tasks that normally require human intelligence—such as learning, reasoning, perception, and decision‑making.
#
# At a high level, AI can be split into:
#
# | Category | What it does | Typical Python tools |
# |----------|--------------|----------------------|
# | **Machine Learning (ML)** | Learns patterns from data to make predictions | `scikit‑learn`, `pandas` |
# | **Deep Learning** | Uses multi‑layer neural networks for complex patterns (images, speech) | `TensorFlow`, `PyTorch` |
# | **Natural Language Processing (NLP)** | Understands or generates human language | `spaCy`, `transformers` |
# | **Computer Vision** | Interprets visual data | `opencv`, `torchvision` |
#
# ### Tiny Python example (ML with scikit‑learn)
#
# ```python
# # A very simple AI that predicts whether a fruit is an apple or orange
# from sklearn.neighbors import KNeighborsClassifier
# import numpy as np
#
# # Features: [weight(g), texture(0=smooth,1=bumpy)]
# X = np.array([[150, 0],   # apple
#               [170, 0],   # apple
#               [130, 1],   # orange
#               [120, 1]])  # orange
# y = np.array(['apple', 'apple', 'orange', 'orange'])
#
# model = KNeighborsClassifier(n_neighbors=3)
# model.fit(X, y)
#
# # Predict a new fruit: 140 g, smooth texture
# print(model.predict([[140, 0]]))   # → ['apple']
# ```
#
# *What’s happening?*
# 1. **Training data** (`X`, `y`) teaches the model the relationship between weight/texture and fruit type.
# 2. The **K‑Nearest Neighbors** algorithm stores the data and, for a new sample, looks at the three closest training points and votes on the label.
# 3. The result (`'apple'`) is the AI’s prediction.
#
# You can run similar snippets in your MCP server code to add lightweight decision‑making features (e.g., routing requests based on simple patterns).
#
# ---
#
# ### Quick takeaways
# - **AI = algorithms that learn from data.**
# - **Python** is the de‑facto language for prototyping because of its rich libraries.
# - For more complex problems, expand to deep learning frameworks or specialized APIs.
#
# ---
#
# #### Suggested next questions
# 1. *Which Python AI library would best complement your MCP server project?*
# 2. *How can I integrate a simple ML model (like the one above) into a Flask or FastAPI service?*
# 3. *What are the key steps to prepare data for training a model in Python?*

# %% [markdown]
# # Chatbot Creating New Memories

# %%
from dotenv import load_dotenv
load_dotenv()

import uuid
from typing import List
from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage
from langchain_core.runnables import RunnableConfig

from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.store.memory import InMemoryStore
from langgraph.store.base import BaseStore

# %%
# ----------------------------
# 1) LTM store
# ----------------------------
store = InMemoryStore()

# %%
extractor_llm  = ChatOpenAI(
    model="openai/gpt-oss-120b",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
)

# %%
class MemoryDecision(BaseModel):
    should_write: bool = Field(description="Whether to store any memories")
    memories: List[str] = Field(default_factory=list, description="Atomic user memories to store")

# %%
memory_extractor = extractor_llm.with_structured_output(MemoryDecision)

# %%
# ----------------------------
# 3) Graph: START -> remember -> END
#    (Creates memories, but does NOT use them to answer)
# ----------------------------
def remember_only_node(state: MessagesState, config: RunnableConfig, store: BaseStore):

    user_id = config["configurable"]["user_id"]
    
    namespace = ("user", user_id, "details")

    # take latest user message
    last_msg = state["messages"][-1].content

    # LLM decides what to store
    decision: MemoryDecision = memory_extractor.invoke(
        [
            SystemMessage(
                content=(
                    "Extract LONG-TERM memories from the user's message.\n"
                    "Only store stable, user-specific info (identity, preferences, ongoing projects).\n"
                    "Do NOT store transient info.\n"
                    "Return should_write=false if nothing is worth storing.\n"
                    "Each memory should be a short atomic sentence."
                )
            ),
            {"role": "user", "content": last_msg},
        ]
    )

    # Write to store (LTM)
    if decision.should_write:
        for mem in decision.memories:
            store.put(namespace, str(uuid.uuid4()), {"data": mem})

    # IMPORTANT: we are NOT using memory, not even responding with the LLM.
    # We just return a fixed acknowledgement.
    return {"messages": [{"role": "assistant", "content": "Noted."}]}

# %%
builder = StateGraph(MessagesState)
builder.add_node("remember", remember_only_node)
builder.add_edge(START, "remember")
builder.add_edge("remember", END)

graph = builder.compile(store=store)

graph

# %%
# ----------------------------
# 4) Demo
# ----------------------------
config = {"configurable": {"user_id": "u1"}}

res = graph.invoke({"messages": [{"role": "user", "content": "Hi my name is Imran Butt"}]},config)
print("Assistant:", res["messages"][-1].content)
# Out:
# Assistant: Noted.

# %%
res = graph.invoke({"messages": [{"role": "user", "content": "I love learning about AI"}]},config)
print("Assistant:", res["messages"][-1].content)
# Out:
# Assistant: Noted.

# %%
res = graph.invoke({"messages": [{"role": "user", "content": "My favorite programming language is Python"}]},config)
print("Assistant:", res["messages"][-1].content)
# Out:
# Assistant: Noted.

# %%
res = graph.invoke({"messages": [{"role": "user", "content": "My favorite programming language is Python"}]},config)
print("Assistant:", res["messages"][-1].content)
# Out:
# Assistant: Noted.

# %%
items = store.search(("user", "u1", "details"))

for item in items:
    print(item.value['data'])
# Out:
# User's name is Imran Butt.
# The user loves learning about AI.
# The user prefers Python as their favorite programming language.
# User's favorite programming language is Python.

# %% [markdown]
# # Memory Without Duplicatoin

# %%
from dotenv import load_dotenv
load_dotenv()

import uuid
from typing import List
from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage
from langchain_core.runnables import RunnableConfig


from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.store.memory import InMemoryStore
from langgraph.store.base import BaseStore
import os

# %%
load_dotenv()
# ----------------------------
# 1) LTM store
# ----------------------------
store = InMemoryStore()

# %%
memory_llm  = ChatOpenAI(
    model="openai/gpt-oss-120b",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
)

# %%
class MemoryItem(BaseModel):
    text: str = Field(description="Atomic user memory as a short sentence")
    is_new: bool = Field(description="True if this memory is NEW and should be stored. False if duplicate/already known.")

# %%
class MemoryDecision(BaseModel):
    should_write: bool = Field(description="Whether to store any memories")
    memories: List[MemoryItem] = Field(default_factory=list, description="Atomic user memories to store")

# %%
memory_extractor = memory_llm.with_structured_output(MemoryDecision)

# %%
MEMORY_PROMPT = """You are responsible for updating and maintaining accurate user memory.

CURRENT USER DETAILS (existing memories):
{user_details_content}

TASK:
- Review the user's latest message.
- Extract user-specific info worth storing long-term (identity, stable preferences, ongoing projects/goals).
- For each extracted item, set is_new=true ONLY if it adds NEW information compared to CURRENT USER DETAILS.
- If it is basically the same meaning as something already present, set is_new=false.
- Keep each memory as a short atomic sentence.
- No speculation; only facts stated by the user.
- If there is nothing memory-worthy, return an empty list.
"""

# %%
def chat_creates_memory_node(state: MessagesState, config: RunnableConfig, store: BaseStore):

    user_id = config["configurable"]["user_id"]

    namespace = ("user", user_id, "details")

    # A) Load existing memories
    existing_items = store.search(namespace)
    existing_texts = [it.value.get("data", "") for it in existing_items if it.value.get("data")]
    user_details_content = "\n".join(f"- {t}" for t in existing_texts) if existing_texts else "(empty)"

    # B) Latest user message
    last_text = state["messages"][-1]

    # C) LLM extracts memories + marks new vs duplicate
    decision: MemoryDecision = memory_extractor.invoke(
        [
            SystemMessage(content=MEMORY_PROMPT.format(user_details_content=user_details_content)),
            {"role": "user", "content": f"USER MESSAGE:\n{last_text}"},
        ]
    )

    # D) Store ONLY new memories
    if decision.should_write:
        for mem in decision.memories:
            if mem.is_new:
                store.put(namespace, str(uuid.uuid4()), {"data": mem.text})

    return {"messages": [{"role": "assistant", "content": "Noted."}]}

# %%
# ----------------------------
# 4) Build graph: START -> chat -> END
# ----------------------------
builder = StateGraph(MessagesState)
builder.add_node("chat", chat_creates_memory_node)
builder.add_edge(START, "chat")
builder.add_edge("chat", END)

graph = builder.compile(store=store)

# %%
config = {"configurable": {"user_id": "u1"}}

# %%
r1 = graph.invoke({"messages": [{"role": "user", "content": "My name is Imran Butt"}]}, config)
print("Assistant:", r1["messages"][-1].content)
# Out:
# Assistant: Noted.

# %%
r2 = graph.invoke({"messages": [{"role": "user", "content": "I like Python for programming."}]}, config)
print("\nAssistant:", r2["messages"][-1].content)
# Out:
# Assistant: Noted.

# %%
# Likely duplicate of the first memory -> is_new should be false -> saved=0
r2 = graph.invoke({"messages": [{"role": "user", "content": "I like Python for programming."}]}, config)
print("\nAssistant:", r2["messages"][-1].content)
# Out:
# Assistant: Noted.

# %%
r1 = graph.invoke({"messages": [{"role": "user", "content": "My name is Imran Butt"}]}, config)
print("Assistant:", r1["messages"][-1].content)
# Out:
# Assistant: Noted.

# %%
for it in store.search(("user", "u1", "details")):
    print(it.value['data'])
# Out:
# The user's name is Imran Butt.
# User likes Python for programming.

# %% [markdown]
# # Merged Workflow

# %%
from dotenv import load_dotenv
load_dotenv()

import uuid
from typing import List
from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage
from langchain_core.runnables import RunnableConfig

from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.store.memory import InMemoryStore
from langgraph.store.base import BaseStore

import os

# %%
load_dotenv()
# ----------------------------
# 1) LTM store
# ----------------------------
store = InMemoryStore()

# %%
# ----------------------------
# 2) System prompt
# ----------------------------
SYSTEM_PROMPT_TEMPLATE = """You are a helpful assistant with memory capabilities.
If user-specific memory is available, use it to personalize your responses based on what you know about the user.
Your goal is to provide relevant, friendly, and tailored assistance that reflects the user’s preferences, context, and past interactions.

If the user’s name or relevant personal context is available, always personalize your responses by:
    – Always Address the user by name (e.g., "Sure, Nitish...") when appropriate
    – Referencing known projects, tools, or preferences (e.g., "your MCP server python based project")
    – Adjusting the tone to feel friendly, natural, and directly aimed at the user

Avoid generic phrasing when personalization is possible.

Use personalization especially in:
    – Greetings and transitions
    – Help or guidance tailored to tools and frameworks the user uses
    – Follow-up messages that continue from past context

Always ensure that personalization is based only on known user details and not assumed.

In the end suggest 3 relevant further questions based on the current response and user profile

The user’s memory (which may be empty) is provided as: {user_details_content}"""

# %%
memory_llm  = ChatOpenAI(
    model="openai/gpt-oss-120b",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
)

# %%
class MemoryItem(BaseModel):
    text: str = Field(description="Atomic user memory")
    is_new: bool = Field(description="True if new, false if duplicate")

# %%
class MemoryDecision(BaseModel):
    should_write: bool
    memories: List[MemoryItem] = Field(default_factory=list)

# %%
memory_extractor = memory_llm.with_structured_output(MemoryDecision)

# %%
MEMORY_PROMPT = """You are responsible for updating and maintaining accurate user memory.

CURRENT USER DETAILS (existing memories):
{user_details_content}

TASK:
- Review the user's latest message.
- Extract user-specific info worth storing long-term (identity, stable preferences, ongoing projects/goals).
- For each extracted item, set is_new=true ONLY if it adds NEW information compared to CURRENT USER DETAILS.
- If it is basically the same meaning as something already present, set is_new=false.
- Keep each memory as a short atomic sentence.
- No speculation; only facts stated by the user.
- If there is nothing memory-worthy, return should_write=false and an empty list.
"""

# %%
# ----------------------------
# 4) Node 1: remember
# ----------------------------
def remember_node(state: MessagesState, config: RunnableConfig, *, store: BaseStore):
    user_id = config["configurable"]["user_id"]
    ns = ("user", user_id, "details")

    # existing memory
    items = store.search(ns)
    existing = "\n".join(it.value["data"] for it in items) if items else "(empty)"

    # last user message
    last_msg = state["messages"][-1].content

    decision: MemoryDecision = memory_extractor.invoke(
        [
            SystemMessage(content=MEMORY_PROMPT.format(user_details_content=existing)),
            {"role": "user", "content": last_msg},
        ]
    )

    if decision.should_write:
        for mem in decision.memories:
            if mem.is_new:
                store.put(ns, str(uuid.uuid4()), {"data": mem.text})

    return {}  # no message change

# %%
chat_llm  = ChatOpenAI(
    model="openai/gpt-oss-120b",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
)

# %%
def chat_node(state: MessagesState, config: RunnableConfig, *, store: BaseStore):
    user_id = config["configurable"]["user_id"]
    ns = ("user", user_id, "details")

    items = store.search(ns)
    user_details = "\n".join(it.value["data"] for it in items) if items else ""

    system_msg = SystemMessage(
        content=SYSTEM_PROMPT_TEMPLATE.format(
            user_details_content=user_details or "(empty)"
        )
    )

    response = chat_llm.invoke([system_msg] + state["messages"])
    return {"messages": [response]}

# %%
# ----------------------------
# 6) Graph
# ----------------------------
builder = StateGraph(MessagesState)
builder.add_node("remember", remember_node)
builder.add_node("chat", chat_node)

builder.add_edge(START, "remember")
builder.add_edge("remember", "chat")
builder.add_edge("chat", END)

graph = builder.compile(store=store)

graph

# %%
# ----------------------------
# 7) Demo
# ----------------------------
config = {"configurable": {"user_id": "u1"}}

# %%
result = graph.invoke({"messages": [{"role": "user", "content": "Hi, my name is Imran BUtt"}]}, config)
result['messages'][-1].content
# Out:
# 'Hello Imran\u202fB\u202fUtt! 👋  \n\nNice to meet you. How can I assist you today? Whether you’re looking for advice on a project, need help with a technical issue, or just want to explore a new topic, I’m here to help.\n\n**Here are a few prompts you might find useful:**\n\n1. **What are you working on right now?** – I can give tips, resources, or code snippets tailored to your current project.  \n2. **Do you need help with a specific programming language or tool?** – Let me know the tech stack (e.g., Python, JavaScript, cloud services) and I can dive straight into relevant examples.  \n3. **Are you looking for learning resources or career advice?** – I can suggest books, courses, or strategies that match your goals.  \n\nFeel free to let me know what’s on your mind!'

# %%
for it in store.search(("user", "u1", "details")):
    print(it.value["data"])
# Out:
# User's name is Imran BUtt.

# %%
result = graph.invoke({"messages": [{"role": "user", "content": "I Love Learning AI"}]}, config)
print(result['messages'][-1].content)
# Out:
# Hey Imran Butt! 🙌 It’s great to hear you’re passionate about AI – there’s so much to explore, and the field keeps evolving every day.
#
# ### Quick starter roadmap
# | **Stage** | **What to dive into** | **Why it helps** |
# |-----------|----------------------|------------------|
# | **Foundations** | *Linear algebra, probability, Python basics* (e.g., “Essence of Linear Algebra” by 3Blue1Brown, **NumPy** tutorials) | These are the math & coding muscles behind every model. |
# | **Core Machine Learning** | *Supervised/unsupervised learning* – Scikit‑learn, “Hands‑On Machine Learning with Scikit‑Learn, Keras & TensorFlow” (Aurélien Géron) | Gives you a solid, practical grasp of classic algorithms. |
# | **Deep Learning** | *Neural nets, CNNs, RNNs, Transformers* – PyTorch or TensorFlow, fast.ai’s “Practical Deep Learning for Coders” | Powers modern AI breakthroughs (vision, language, games). |
# | **Specialized Tracks** | • **Computer Vision** – Detectron2, OpenCV<br>• **Natural Language Processing** – Hugging Face 🤗 Transformers, spaCy<br>• **Reinforcement Learning** – OpenAI Gym, Stable‑Baselines3 | Lets you focus on the area that excites you most. |
# | **Hands‑On Projects** | • Build a sentiment‑analysis app with Hugging Face<br>• Train a simple image classifier on CIFAR‑10<br>• Create a ChatGPT‑style chatbot using OpenAI’s API | Projects cement concepts and look great on a portfolio. |
# | **Community & Staying Current** | • Follow AI newsletters (“Import AI”, “The Batch”)<br>• Join Discord/Slack groups (e.g., r/MachineLearning, AI Hub)<br>• Attend virtual meet‑ups or Kaggle competitions | Keeps you up‑to‑date and gives you feedback loops. |
#
# ### Quick tip for accelerating learning
# **Start a “learning notebook.”**
# Every time you finish a tutorial or read a paper, jot down:
# - The key idea in one sentence
# - A tiny code snippet you wrote
# - A question or “next step” you want to explore
#
# Over time this becomes a personal mini‑textbook you can revisit before interviews, projects, or just to reinforce memory.
#
# ---
#
# #### Want to dive deeper? Here are three follow‑up questions that can help me tailor the next steps for you:
#
# 1. **Which AI sub‑domain excites you the most right now – vision, language, reinforcement learning, or something else?**
# 2. **What’s your current programming background (e.g., comfortable with Python, have used PyTorch/TensorFlow, or just starting out)?**
# 3. **Do you prefer structured courses, hands‑on project guides, research papers, or a mix of all three for learning?**
#
# Feel free to pick any, and we can map out a more detailed plan just for you!

# %%
for it in store.search(("user", "u1", "details")):
    print(it.value["data"])
# Out:
# User's name is Imran BUtt.
# User loves learning AI.

# %%
result = graph.invoke({"messages": [{"role": "user", "content": "Explain GenAI simply"}]}, config)
print(result['messages'][-1].content)
# Out:
# Sure, Imran Butt — here’s a quick, plain‑language rundown of what **generative AI (Gen AI)** is all about.
#
# ---
#
# ## 1. What “generative” means
# - **Generative** ≈ *creates something new*.
# - In AI, a generative model learns patterns from existing data (text, images, music, code, etc.) and then *generates* fresh content that follows those patterns.
#
# ## 2. The basic idea in a nutshell
# 1. **Training phase**
#    - Feed the model a huge collection of examples (e.g., millions of sentences or pictures).
#    - The model adjusts its internal parameters so it can predict the next piece of data (the next word, pixel, note, etc.) given the context.
#
# 2. **Generation phase**
#    - Give the trained model a prompt or a starting point.
#    - It “fills in” the rest, producing text, an image, a melody, or even code that never existed before but looks like it could have come from the original dataset.
#
# ## 3. How it works (very high‑level)
# - Most modern Gen AI uses **deep neural networks**, especially **Transformer** architectures (think GPT, BERT, Stable Diffusion, DALL·E).
# - The model learns a probability distribution \(P(\text{next token} \mid \text{previous tokens})\).
# - During generation, it samples from this distribution—sometimes taking the most likely token (deterministic) or adding a bit of randomness (creative).
#
# ## 4. Everyday analogies
# | Domain | Analogy |
# |--------|----------|
# | **Text** | Imagine you’ve read thousands of novels. When asked to write a new story, you pick words that *feel right* based on what you’ve seen. |
# | **Images** | Think of a painter who has studied countless landscapes. When you say “sunset over a city,” the painter mixes colors and brushstrokes you’ve seen before to create a brand‑new picture. |
# | **Music** | It’s like a composer who has listened to every jazz standard; given a chord progression, they improvise a fresh solo that follows the style. |
#
# ## 5. Why it matters
# - **Productivity boost** – draft emails, write code snippets, create marketing graphics.
# - **Creativity aid** – brainstorm ideas, generate art, compose music.
# - **Personalization** – tailor content (recommendations, tutoring, design) to individual preferences.
#
# ## 6. Common misconceptions
# | Myth | Reality |
# |------|----------|
# | “Gen AI *understands* the content.” | It captures statistical patterns, not true comprehension. |
# | “It’s always perfect.” | Output can be wrong, biased, or nonsensical; human oversight is still needed. |
# | “Only big tech can use it.” | Open‑source models (e.g., LLaMA, Stable Diffusion) let hobbyists and researchers experiment on modest hardware. |
#
# ## 7. A quick visual of the workflow
# ```
# Data (text, images, audio) → Training (large neural net) → Saved Model → Prompt → Generated Output
# ```
#
# ---
#
# ### TL;DR
# Generative AI learns from massive examples, then uses that knowledge to *create* new, coherent content that mimics the style and structure of the training data. It’s like a super‑experienced apprentice that can write, draw, or compose on demand.
#
# ---
#
# **What would you like to explore next?** Here are three ideas that might match your AI curiosity:
#
# 1. **“What are the main families of generative models (e.g., GANs, VAEs, Transformers) and when should I use each?”**
# 2. **“Can you walk me through building a simple text‑generation model with Python and Hugging Face?”**
# 3. **“What are the biggest ethical and bias concerns with Gen AI, and how can developers mitigate them?”**
#
# Just let me know which direction you’d like to go!

# %%
for it in store.search(("user", "u1", "details")):
    print(it.value["data"])
# Out:
# User's name is Imran BUtt.
# User loves learning AI.
