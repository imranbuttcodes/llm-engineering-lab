# %%
# !pip install -q "lm_eval[api]"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 686.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 25.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 7.1 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for word2number (setup.py) ... done

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter OpenAI API key: ")
# Out:
# Enter OpenAI API key: ··········

# %%
# !lm-eval run \
    --model openai-chat-completions \
    --model_args "model=gpt-5.6-luna,num_concurrent=5,max_retries=5" \
    --tasks gsm8k_cot \
    --num_fewshot 8 \
    --apply_chat_template \
    --limit 20 \
    --output_path ./gsm8k_results \
    --log_samples
# Out:
# 2026-07-15:15:55:00 WARNING  [config.evaluate_config:287] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-07-15:15:55:00 INFO     [config.evaluate_config:307] Using default fewshot_as_multiturn=True.
# 2026-07-15:15:55:14 INFO     [_cli.run:388] Selected Tasks: ['gsm8k_cot']
# 2026-07-15:15:55:17 INFO     [evaluator:214] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-07-15:15:55:17 INFO     [evaluator:239] Initializing openai-chat-completions model, with arguments: {'model': 'gpt-5.6-luna', 'num_concurrent': 5, 'max_retries': 5}
# 2026-07-15:15:55:17 INFO     [models.api_models:179] Using max length 2048 - 1
# 2026-07-15:15:55:17 INFO     [models.api_models:200] Using tokenizer None
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 100% 7.93k/7.93k [00:00<00:00, 3.00MB/s]
# main/train-00000-of-00001.parquet: 100% 2.31M/2.31M [00:01<00:00, 1.48MB/s]
# main/test-00000-of-00001.parquet: 100% 419k/419k [00:01<00:00, 360kB/s]
# Generating train split: 100% 7473/7473 [00:00<00:00, 129036.12 examples/s]
# Generating test split: 100% 1319/1319 [00:00<00:00, 217840.88 examples/s]
# 2026-07-15:15:55:24 INFO     [evaluator_utils:446] Selected tasks:
# 2026-07-15:15:55:24 INFO     [evaluator_utils:480] Task: gsm8k_cot (gsm8k/gsm8k-cot.yaml)
# 2026-07-15:15:55:24 INFO     [evaluator:314] gsm8k_cot: Using gen_kwargs: {'do_sample': False, 'until': ['Q:', '</s>', '<|im_end|>']}
# 2026-07-15:15:55:24 WARNING  [evaluator:333] Overwriting default num_fewshot of gsm8k_cot from 8 to 8
# 2026-07-15:15:55:24 INFO     [api.task:312] Building contexts for gsm8k_cot on rank 0...
# 100% 20/20 [00:00<00:00, 57.38it/s]
# 2026-07-15:15:55:24 INFO     [evaluator:585] Running generate_until requests
# 2026-07-15:15:55:24 INFO     [models.api_models:747] Tokenized requests are disabled. Context + generation length is not checked.
# Requesting API: 100% 20/20 [00:11<00:00,  1.77it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2026-07-15:15:55:41 INFO     [loggers.evaluation_tracker:247] Saving results aggregated
# 2026-07-15:15:55:41 INFO     [loggers.evaluation_tracker:119] Saving per-task samples to gsm8k_results/gpt-5.6-luna/*.jsonl
# openai-chat-completions ({'model': 'gpt-5.6-luna', 'num_concurrent': 5, 'max_retries': 5}), gen_kwargs: ({}), limit: 20.0, num_fewshot: 8, batch_size: 1
# |  Tasks  |Version|     Filter     |n-shot|  Metric   |   |Value|   |Stderr|
# |---------|------:|----------------|-----:|-----------|---|----:|---|-----:|
# |gsm8k_cot|      3|flexible-extract|     8|exact_match|↑  | 0.90|±  |0.0688|
# |         |       |strict-match    |     8|exact_match|↑  | 0.05|±  |0.0500|
